# %%
import numpy as np

# %%
# LIST OF POINTS

# %%
coords = [[np.random.randint(-39,65), np.random.randint(12,88)] for _ in range(1000)]

# %%
print(coords)
# Out:
# [[13, 86], [49, 79], [57, 34], [42, 29], [49, 52], [-37, 80], [17, 26], [13, 42], [19, 64], [53, 57], [-3, 67], [36, 51], [0, 52], [61, 75], [27, 58], [61, 68], [51, 41], [-13, 24], [3, 24], [-27, 40], [63, 28], [49, 48], [-18, 53], [-27, 20], [12, 86], [46, 21], [50, 82], [24, 70], [55, 75], [49, 84], [24, 85], [14, 63], [-18, 71], [28, 77], [-21, 77], [43, 61], [38, 28], [42, 24], [-18, 53], [40, 32], [28, 34], [62, 79], [46, 23], [-20, 70], [-1, 28], [-15, 76], [-17, 74], [-13, 33], [21, 44], [-12, 65], [-20, 22], [-38, 51], [30, 28], [-19, 64], [26, 18], [-1, 81], [10, 61], [26, 25], [10, 76], [34, 23], [-34, 25], [44, 62], [-9, 67], [53, 36], [14, 85], [31, 80], [34, 67], [-3, 33], [35, 17], [62, 16], [-4, 42], [62, 72], [14, 41], [36, 83], [60, 39], [27, 28], [13, 52], [31, 54], [49, 52], [1, 46], [41, 70], [10, 60], [-22, 36], [13, 74], [29, 82], [11, 33], [4, 22], [20, 34], [-20, 16], [26, 45], [6, 48], [62, 54], [6, 58], [30, 19], [-5, 17], [-21, 44], [54, 55], [63, 49], [-3
# ...

# %%
coords = np.asarray(coords)

# %%
print(coords)
# Out:
# [[ 13  86]
#  [ 49  79]
#  [ 57  34]
#  ...
#  [-38  78]
#  [ 14  49]
#  [  2  41]]

# %%
coords.shape
# Out:
# (1000, 2)

# %%
# ARRAY OF POINTS

coords = np.random.randint(-100,100,(10,2))

# %% [markdown]
# # Original Data

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(coords[:,0], coords[:,1], color='blue', s=0.1)
plt.xlabel('x coordinate')
plt.ylabel('y coordinate')
plt.xlim(-100,100)
plt.ylim(-200,200)
plt.title('Original data')
# Out:
# Text(0.5, 1.0, 'Original data')

# %% [markdown]
# # PCA Projection to 2D

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=1)

# %%
principal_components = pca.fit_transform(coords)

# %%
print(principal_components)
# Out:
# [[  5.50568473]
#  [ 40.39018126]
#  [ 42.87028694]
#  [ 27.37438867]
#  [ 37.113718  ]
#  [-44.85290427]
#  [  2.19509417]
#  [  0.16626314]
#  [  8.79163226]
#  [ 41.69090934]
#  [-12.68173013]
#  [ 24.08844114]
#  [-11.52415833]
#  [ 51.81609595]
#  [ 16.00440709]
#  [ 50.96664251]
#  [ 37.76408205]
#  [-27.82589845]
#  [-11.94414291]
#  [-39.78082669]
#  [ 48.09784232]
#  [ 36.62831604]
#  [-29.26978282]
#  [-42.2078365 ]
#  [  4.51307501]
#  [ 30.37402363]
#  [ 41.74684245]
#  [ 14.48278381]
#  [ 45.86043762]
#  [ 40.99693371]
#  [ 16.30304117]
#  [  3.70723317]
#  [-27.08547398]
#  [ 19.30267613]
#  [-29.3352002 ]
#  [ 32.2502141 ]
#  [ 23.28259929]
#  [ 26.76763621]
#  [-29.26978282]
#  [ 25.7532207 ]
#  [ 14.08460503]
#  [ 53.29410763]
#  [ 30.61672461]
#  [-29.19204392]
#  [-15.42917983]
#  [-23.50089237]
#  [-25.72881279]
#  [-26.73374403]
#  [  8.34984189]
#  [-21.8579186 ]
#  [-35.01686747]
#  [-49.36467822]
#  [ 15.34172152]
#  [-28.92753714]
#  [ 10.15777773]
# ...

# %%
zero_y = np.zeros((1000,1))

# %%
new_principal_components = np.insert(principal_components, 0, 0, axis=1)

# %%
print(new_principal_components)
# Out:
# [[  0.         -48.32180086]
#  [  0.         -30.5356569 ]
#  [  0.         -16.27047995]
#  ...
#  [  0.          84.32645834]
#  [  0.         -26.69576648]
#  [  0.          43.73587709]]

# %%
new_principal_components.shape
# Out:
# (1000, 2)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(principal_components[:,0], zero_y[:,0],color='red', s=0.1)
plt.xlabel('x coordinate')
plt.ylabel('y coordinate')
plt.xlim(-100,100)
plt.ylim(-2,2)
plt.title('First PC')
# Out:
# Text(0.5, 1.0, 'First PC')

# %%
xyz=np.array(np.random.random((100,3)))

# %%
print(xyz)
# Out:
# [[0.7941389  0.93483374 0.86264626]
#  [0.9142825  0.90490651 0.58788783]
#  [0.37152593 0.59935837 0.55419458]
#  [0.57355384 0.30833051 0.90605133]
#  [0.376815   0.18792722 0.26564035]
#  [0.21818386 0.25066499 0.8320689 ]
#  [0.77710811 0.36877231 0.94811416]
#  [0.35869823 0.46923449 0.07096759]
#  [0.27183229 0.78381643 0.3510629 ]
#  [0.48700054 0.63284804 0.14671081]
#  [0.8980854  0.1506808  0.87547946]
#  [0.13881002 0.85178744 0.56005568]
#  [0.8622948  0.51137471 0.91115139]
#  [0.55335113 0.40517892 0.53088574]
#  [0.38981644 0.35503754 0.43456089]
#  [0.60372654 0.33041008 0.28683594]
#  [0.51057117 0.39078908 0.66425238]
#  [0.81328023 0.11386347 0.7104848 ]
#  [0.15837567 0.25560935 0.1506835 ]
#  [0.1687912  0.424607   0.71042542]
#  [0.90340683 0.3736136  0.73506448]
#  [0.80454156 0.9805012  0.76343524]
#  [0.42329671 0.56959583 0.46051793]
#  [0.13024533 0.41777601 0.38638966]
#  [0.93982891 0.23894528 0.70222695]
#  [0.8962473  0.09656937 0.77752851]
# ...

# %%
x_coordinate = [np.random.randint(45) for i in range (1000)]

# %%
y_coordinate = [np.random.randint(24) for i in range (1000)]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x_coordinate, y_coordinate, color="green", s=0.10)
plt.xlim(-50,70)
plt.ylim(-50,70)
plt.title("Original data")
# Out:
# Text(0.5, 1.0, 'Original data')
